# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd

np.set_printoptions(linewidth=150)

# %% [markdown]
# # Preparing the dataset
#
# password = ".tie5Roanl"
#
#     H.char -> Hold time
#     DD.char1.char2 -> Time from when char1 was pressed to when char2 was pressed
#     UD.char1.char2 -> Time from when char1 was released to when char2 was pressed

# %%
original_data = pd.read_csv("DSL-StrongPasswordData.csv")

# %%
original_data
# Out:
#       subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0        s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1        s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2        s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3        s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4        s002             1    5    0.1249       0.2317       0.1068  0.0895
# ...       ...           ...  ...       ...          ...          ...     ...
# 20395    s057             8   46    0.0884       0.0685      -0.0199  0.1095
# 20396    s057             8   47    0.0655       0.0630      -0.0025  0.0910
# 20397    s057             8   48    0.0939       0.1189       0.0250  0.1008
# 20398    s057             8   49    0.0923       0.1294       0.0371  0.0913
# 20399    s057             8   50    0.0596       0.1310       0.0714  0.0992
#
#        DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0      0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1      0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2      0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3      0.2495  0.1436  0.1040  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4      0.1676  0.0781  0.0903  ...  0.1312  0.1582  0.0270  0.0884  0.2517
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 20395  0.1290  0.0195  0.0945  ...  0.1219  0.1383  0.0164  0.0820  0.1329
# 20396  0.1148  0.0238  0.0916  ...  0.1008  0.0512 -0.0496  0.1037  0.0868
# 20397  0.1122  0.0114  0.0721  ...  0.0913  0.1169  0.0256  0.0689  0.1311
# 20398  0.0990  0.0077  0.0992  ...  0.0882  0.0821 -0.0061  0.0576  0.0697
# 20399  0.1103  0.0111  0.0998  ...  0.0969  0.0784 -0.0185  0.0790  0.1133
#
#        UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# 0      0.2583  0.1338       0.3509       0.2171    0.0742
# 1      0.1496  0.0839       0.2756       0.1917    0.0747
# 2      0.1533  0.1085       0.2847       0.1762    0.0945
# 3      0.1475  0.0845       0.3232       0.2387    0.0813
# 4      0.1633  0.0903       0.2517       0.1614    0.0818
# ...       ...     ...          ...          ...       ...
# 20395  0.0509  0.1005       0.2054       0.1049    0.1047
# 20396 -0.0169  0.1445       0.2206       0.0761    0.1198
# 20397  0.0622  0.1034       0.2017       0.0983    0.0905
# 20398  0.0121  0.0979       0.1917       0.0938    0.0931
# 20399  0.0343  0.0807       0.1993       0.1186    0.1018
#
# [20400 rows x 34 columns]

# %%
data = original_data.drop(["sessionIndex","rep"],axis=1)

data
# Out:
#       subject  H.period  DD.period.t  UD.period.t     H.t  DD.t.i  UD.t.i  \
# 0        s002    0.1491       0.3979       0.2488  0.1069  0.1674  0.0605
# 1        s002    0.1111       0.3451       0.2340  0.0694  0.1283  0.0589
# 2        s002    0.1328       0.2072       0.0744  0.0731  0.1291  0.0560
# 3        s002    0.1291       0.2515       0.1224  0.1059  0.2495  0.1436
# 4        s002    0.1249       0.2317       0.1068  0.0895  0.1676  0.0781
# ...       ...       ...          ...          ...     ...     ...     ...
# 20395    s057    0.0884       0.0685      -0.0199  0.1095  0.1290  0.0195
# 20396    s057    0.0655       0.0630      -0.0025  0.0910  0.1148  0.0238
# 20397    s057    0.0939       0.1189       0.0250  0.1008  0.1122  0.0114
# 20398    s057    0.0923       0.1294       0.0371  0.0913  0.0990  0.0077
# 20399    s057    0.0596       0.1310       0.0714  0.0992  0.1103  0.0111
#
#           H.i  DD.i.e  UD.i.e  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0      0.1169  0.2212  0.1043  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1      0.0908  0.1357  0.0449  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2      0.0821  0.1542  0.0721  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3      0.1040  0.2038  0.0998  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4      0.0903  0.1589  0.0686  ...  0.1312  0.1582  0.0270  0.0884  0.2517
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 20395  0.0945  0.0757 -0.0188  ...  0.1219  0.1383  0.0164  0.0820  0.1329
# 20396  0.0916  0.0636 -0.0280  ...  0.1008  0.0512 -0.0496  0.1037  0.0868
# 20397  0.0721  0.0462 -0.0259  ...  0.0913  0.1169  0.0256  0.0689  0.1311
# 20398  0.0992  0.0897 -0.0095  ...  0.0882  0.0821 -0.0061  0.0576  0.0697
# 20399  0.0998  0.0813 -0.0185  ...  0.0969  0.0784 -0.0185  0.0790  0.1133
#
#        UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# 0      0.2583  0.1338       0.3509       0.2171    0.0742
# 1      0.1496  0.0839       0.2756       0.1917    0.0747
# 2      0.1533  0.1085       0.2847       0.1762    0.0945
# 3      0.1475  0.0845       0.3232       0.2387    0.0813
# 4      0.1633  0.0903       0.2517       0.1614    0.0818
# ...       ...     ...          ...          ...       ...
# 20395  0.0509  0.1005       0.2054       0.1049    0.1047
# 20396 -0.0169  0.1445       0.2206       0.0761    0.1198
# 20397  0.0622  0.1034       0.2017       0.0983    0.0905
# 20398  0.0121  0.0979       0.1917       0.0938    0.0931
# 20399  0.0343  0.0807       0.1993       0.1186    0.1018
#
# [20400 rows x 32 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data.iloc[:,1:],data["subject"],
                                                    stratify = data["subject"],
                                                    test_size=0.25)

y_train_dummy = pd.get_dummies(y_train)
y_test_dummy= pd.get_dummies(y_test)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

minmax = MinMaxScaler()
X_train_minmax = scaler.fit_transform(X_train)
X_test_minmax = scaler.transform(X_test)

# %%
model = tf.keras.Sequential([
    keras.layers.Input(shape=(31,)),
    keras.layers.Dense(128,activation="relu"),
    keras.layers.Dense(256,activation="relu"),
    keras.layers.Dense(256,activation="relu"),
    keras.layers.Dense(51,activation="softmax")   
])

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

model.fit(X_train_scaled,y_train_dummy,epochs=20,validation_data=(X_test_scaled,y_test_dummy),verbose=2)
# Out:
# Epoch 1/20
# 479/479 - 1s - loss: 1.2307 - accuracy: 0.6842 - val_loss: 0.7420 - val_accuracy: 0.7986
# Epoch 2/20
# 479/479 - 1s - loss: 0.5248 - accuracy: 0.8490 - val_loss: 0.5432 - val_accuracy: 0.8463
# Epoch 3/20
# 479/479 - 1s - loss: 0.3987 - accuracy: 0.8818 - val_loss: 0.4590 - val_accuracy: 0.8663
# Epoch 4/20
# 479/479 - 1s - loss: 0.3023 - accuracy: 0.9093 - val_loss: 0.3783 - val_accuracy: 0.8914
# Epoch 5/20
# 479/479 - 1s - loss: 0.2409 - accuracy: 0.9249 - val_loss: 0.4191 - val_accuracy: 0.8814
# Epoch 6/20
# 479/479 - 1s - loss: 0.2029 - accuracy: 0.9350 - val_loss: 0.4190 - val_accuracy: 0.8837
# Epoch 7/20
# 479/479 - 1s - loss: 0.1800 - accuracy: 0.9442 - val_loss: 0.3654 - val_accuracy: 0.8986
# Epoch 8/20
# 479/479 - 1s - loss: 0.1355 - accuracy: 0.9564 - val_loss: 0.3481 - val_accuracy: 0.9018
# Epoch 9/20
# 479/479 - 1s - loss: 0.1143 - accuracy: 0.9630 - val_loss: 0.3488 - val_accuracy: 0.9075
# Epoch 10/20
# 479/479 - 1s - loss: 0.1044 - accuracy: 0.9652 - val_loss: 0.3483 - val_accuracy: 0.9078
# Epoch 11/20
# 479/479 - 1s - loss: 0.0867 - accuracy: 0.9712 - val_loss: 0.3329 - val_accuracy: 0.9135
# Epoch 12/20
# 479/479 - 1s - loss: 0.0792 - accuracy: 0.9739 - val_loss: 0.3759 - val_accuracy: 0.9135
# Epoch 13/20
# 479/479 - 1s - loss: 0.0589 - accuracy: 0.9814 - val_loss: 0.4052 - val_accuracy: 0.9012
# Epoch 14/20
# 479/479 - 1s - loss: 0.0633 - accuracy: 0.9790 - val_loss: 0.4148 - val_accuracy: 0.9014
# Epoch 15/20
# 479/479 - 1s - loss: 0.0499 - accuracy: 0.9842 - val_loss: 0.4061 - val_accuracy: 0.9141
# Epoch 16/20
# 479/479 - 1s - loss: 0.0627 - accuracy: 0.9808 - val_loss: 0.4449 - val_accuracy: 0.9022
# Epoch 17/20
# 479/479 - 1s - loss: 0.0556 - accuracy: 0.9816 - val_loss: 0.4086 - val_accuracy: 0.9094
# Epoch 18/20
# 479/479 - 1s - loss: 0.0418 - accuracy: 0.9865 - val_loss: 0.4228 - val_accuracy: 0.9118
# Epoch 19/20
# 479/479 - 1s - loss: 0.0486 - accuracy: 0.9831 - val_loss: 0.4499 - val_accuracy: 0.9073
# Epoch 20/20
# 479/479 - 1s - loss: 0.0367 - accuracy: 0.9880 - val_loss: 0.5130 - val_accuracy: 0.9016

# %% [markdown]
# # Results:
#
# With 300 instances for the training set and 100 instances for the test set per each user, Neural Network that does multiclass classification gets a validation accuracy of **91%**
#
# Lowering the number of instances reduces the results drastically.

# %%
y_train.unique()
# Out:
# array(['s036', 's020', 's037', 's026', 's053', 's022', 's018', 's031', 's056', 's034', 's027', 's002', 's038', 's047', 's032', 's003', 's021',
#        's029', 's019', 's041', 's054', 's055', 's007', 's028', 's010', 's015', 's040', 's043', 's057', 's013', 's011', 's008', 's035', 's051',
#        's005', 's048', 's025', 's012', 's004', 's016', 's050', 's046', 's024', 's044', 's033', 's049', 's039', 's030', 's017', 's052', 's042'],
#       dtype=object)

# %%
X_train
# Out:
#        H.period  DD.period.t  UD.period.t     H.t  DD.t.i  UD.t.i     H.i  \
# 12313    0.0449       0.4433       0.3984  0.0538  0.1883  0.1345  0.0544
# 6317     0.0515       0.3913       0.3398  0.0942  0.1586  0.0644  0.0895
# 12584    0.1142       0.1184       0.0042  0.0820  0.1717  0.0897  0.1098
# 8009     0.0768       0.1651       0.0883  0.0650  0.1088  0.0438  0.0723
# 18542    0.1142       0.1566       0.0424  0.0554  0.1008  0.0454  0.0871
# ...         ...          ...          ...     ...     ...     ...     ...
# 3147     0.0597       0.0950       0.0353  0.1592  0.1465 -0.0127  0.1025
# 461      0.0969       0.2003       0.1034  0.0898  0.1487  0.0589  0.0858
# 9199     0.0747       0.1746       0.0999  0.0578  0.1151  0.0573  0.0679
# 14027    0.1757       0.1692      -0.0065  0.1354  0.1837  0.0483  0.0778
# 14693    0.1353       0.2948       0.1595  0.0686  0.1533  0.0847  0.0910
#
#        DD.i.e  UD.i.e     H.e  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 12313  0.3862  0.3318  0.0575  ...  0.0636  0.3413  0.2777  0.0372  0.5235
# 6317   0.0990  0.0095  0.1077  ...  0.1138  0.1281  0.0143  0.0523  0.0330
# 12584  0.1087 -0.0011  0.1093  ...  0.0960  0.1185  0.0225  0.0881  0.1440
# 8009   0.1183  0.0460  0.0763  ...  0.0781  0.1357  0.0576  0.0591  0.1631
# 18542  0.0857 -0.0014  0.0484  ...  0.1008  0.0726 -0.0282  0.1172  0.0665
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 3147   0.1363  0.0338  0.1124  ...  0.1017  0.1461  0.0444  0.1510  0.0908
# 461    0.1537  0.0679  0.0982  ...  0.1146  0.1363  0.0217  0.0771  0.1270
# 9199   0.0832  0.0153  0.0591  ...  0.0668  0.0956  0.0288  0.0581  0.1404
# 14027  0.1329  0.0551  0.1733  ...  0.1498  0.1710  0.0212  0.0773  0.1862
# 14693  0.1965  0.1055  0.0749  ...  0.0989  0.2192  0.1203  0.1557  0.0889
#
#        UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# 12313  0.4863  0.0370       0.4944       0.4574    0.0478
# 6317  -0.0193  0.1549       0.1994       0.0445    0.0824
# 12584  0.0559  0.1253       0.2191       0.0938    0.1308
# 8009   0.1040  0.0969       0.2206       0.1237    0.0979
# 18542 -0.0507  0.1322       0.2531       0.1209    0.0889
# ...       ...     ...          ...          ...       ...
# 3147  -0.0602  0.1623       0.1437      -0.0186    0.1341
# 461    0.0499  0.0977       0.2216       0.1239    0.0689
# 9199   0.0823  0.0599       0.2746       0.2147    0.0631
# 14027  0.1089  0.0947       0.2684       0.1737    0.1171
# 14693 -0.0668  0.1338       0.3887       0.2549    0.1335
#
# [15300 rows x 31 columns]

# %%
train_dataset = X_train.copy()
train_dataset["subject"] = y_train

train_dataset.sort_values("subject",axis=0,inplace=True)
train_dataset.reset_index(drop=True,inplace=True)

# %%
user2 = train_dataset.loc[train_dataset.subject=="s002"].drop("subject",axis=1)

# %%
from sklearn.svm import OneClassSVM

svm = OneClassSVM(kernel="rbf",nu=0.5,gamma=0.9)

svm.fit(user2)

result = svm.predict(train_dataset.drop("subject",axis=1))
positives = np.where(result==1)[0]
print(positives)
print(len(positives))
# Out:
# [    2     4     6 ... 14963 15010 15259]
# 1081

# %% [markdown]
# # LOF

# %% [markdown]
# ## To Do:
#
#     - Try grid_searching for every user independently to find the contamination values such that errors are equal
#
#     - Custom Scorer:
#
#     import numpy as np
#
#     def scorer_(estimator, X, y):
#         # Your criterion here
#         if np.allclose(estimator.coef_, np.zeros_like(estimator.coef_)):
#             return 0
#         else:
#             return estimator.score(X, y)
#
#     learner = sklearn.grid_search.GridSearchCV(...
#                                                scoring=scorer_)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt


def calculate_metrics(conf_matrix):
    true_positive_rate = conf_matrix[1,1] / conf_matrix[1,:].sum()
    true_negative_rate = conf_matrix[0,0] / conf_matrix[0,:].sum()

    return true_positive_rate, true_negative_rate


def display_confusion_matrix(conf_matrix):
    print(conf_matrix)
        
    fig, ax = plt.subplots(figsize=(10,10))
    display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix,display_labels=["Imposter","User"])
    display.plot(cmap=plt.cm.Blues, values_format="d",ax=ax)

    true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)
    
    print(f"True positive rate: {true_positive_rate}")
    print(f"True negative rate: {true_negative_rate}")

def test_function(dataset, class_column = "user"):
    
    if class_column not in dataset.columns:
        msg = (f"class_column \"{class_column}\" does not exist in dataset")
        raise KeyError(msg)
        
    class_list = dataset[class_column].unique()
    labels = dataset[class_column].copy()
    tpr_list = np.array([])
    tnr_list = np.array([])

    for i in class_list:
        
        print(f"User #{i}")
        
        # Training LOF on 50 randomly sampled user data
        train_set = dataset.loc[dataset[class_column]==i].drop(class_column,axis=1).sample(50,random_state=42)
        train_set_index = train_set.index
        
        # Dropping the previously selected samples from the test_dataset
        test_dataset = dataset.drop(train_set_index)
        # Preparing labels for each user
        labels = test_dataset[class_column].copy()
        user_labels = labels.copy()
        user_labels[user_labels != i] = -1
        user_labels[user_labels == i] = 1
        user_labels = user_labels.astype("int32")
        
        # Scaling the train_set
        scaler = StandardScaler()
        scaled_train_set = pd.DataFrame(scaler.fit_transform(train_set),columns=train_set.columns)
        
        # Training the Classifier on the scaled_train_set
        lof = LocalOutlierFactor(n_neighbors=10, novelty=True, contamination=0.13, metric="manhattan")
        lof.fit(scaled_train_set)
        
        # Testing the Classifier on the scaled test_set
        scaled_test_dataset = pd.DataFrame(scaler.transform(test_dataset.drop(class_column,axis=1)),columns=train_set.columns)
        results = lof.predict(scaled_test_dataset)

        conf_matrix = confusion_matrix(user_labels.values,results)
        #display_confusion_matrix(conf_matrix)
        true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)
        tpr_list = np.append(tpr_list,true_positive_rate)
        tnr_list = np.append(tnr_list,true_negative_rate)
        
    average_tpr = tpr_list.mean()
    average_tnr = tnr_list.mean()
    
    print(f"Average true positive rate: {average_tpr}")
    print(f"Average true negative rate: {average_tnr}")
    
test_function(train_dataset, class_column="subject")
# Out:
# User #s002
# User #s003
# User #s004
# User #s005
# User #s007
# User #s008
# User #s010
# User #s011
# User #s012
# User #s013
# User #s015
# User #s016
# User #s017
# User #s018
# User #s019
# User #s020
# User #s021
# User #s022
# User #s024
# User #s025
# User #s026
# User #s027
# User #s028
# User #s029
# User #s030
# User #s031
# User #s032
# User #s033
# User #s034
# User #s035
# User #s036
# User #s037
# User #s038
# User #s039
# User #s040
# User #s041
# User #s042
# User #s043
# User #s044
# User #s046
# User #s047
# User #s048
# User #s049
# User #s050
# User #s051
# User #s052
# User #s053
# User #s054
# User #s055
# User #s056
# User #s057
# Average true positive rate: 0.8195294117647058
# Average true negative rate: 0.8783477124183008

# %% [markdown]
# ### Results with contamination = 0.15, 50 training samples
# 1. Euclidian:
#     - Average true positive rate: 0.823921568627451
#     - Average true negative rate: 0.8225411764705882
#
#
# 2. **Manhattan**:
#     - Average true positive rate: 0.8273202614379084
#     - Average true negative rate: 0.8727764705882355
#
#
# 3. Squared Euclidian:
#     - Average true positive rate: 0.8218300653594771
#     - Average true negative rate: 0.8183346405228757

# %%
"""


from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt


def calculate_metrics(conf_matrix):
    true_positive_rate = conf_matrix[1,1] / conf_matrix[1,:].sum()
    true_negative_rate = conf_matrix[0,0] / conf_matrix[0,:].sum()

    return true_positive_rate, true_negative_rate


def display_confusion_matrix(conf_matrix):
    print(conf_matrix)
        
    fig, ax = plt.subplots(figsize=(10,10))
    display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix,display_labels=["Imposter","User"])
    display.plot(cmap=plt.cm.Blues, values_format="d",ax=ax)

    true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)
    
    print(f"True positive rate: {true_positive_rate}")
    print(f"True negative rate: {true_negative_rate}")

def test_function(dataset, class_column = "user"):
    
    if class_column not in dataset.columns:
        msg = (f"class_column \"{class_column}\" does not exist in dataset")
        raise KeyError(msg)

    #sss = StratifiedShuffleSplit(2,test_size=0.01,random_state=42)
    #generator = sss.split(train_dataset,train_dataset["subject"])
    #_, indices = next(generator)
    #stratified_dataset = dataset.iloc[indices]
    #dataset = pd.concat([stratified_dataset,dataset.loc[dataset.subject == "s040"][:75]])
        
    class_list = dataset[class_column].unique()
    labels = dataset[class_column].copy()
    dataset = dataset.drop(class_column,axis=1)
    tpr_list = np.array([])
    tnr_list = np.array([])

    for i in class_list:
        
        print(f"User #{i}")
        
        user_labels = labels.copy()
        user_labels[user_labels != i] = -1
        user_labels[user_labels == i] = 1
        user_labels = user_labels.astype("int32")
        
        # Selecting only the first 50 elements to train on
        
        train_set = dataset.loc[user_labels==1].sample(50,random_state=42)
        drop_train_rows = train_set.index
        

        scaler = StandardScaler()
        scaled_train_set = pd.DataFrame(scaler.fit_transform(train_set),columns=train_set.columns)
        
        lof = LocalOutlierFactor(n_neighbors=10, novelty=True, contamination=0.15)
        lof.fit(scaled_train_set)
        
        scaled_dataset = pd.DataFrame(scaler.transform(dataset.drop(drop_train_rows)),columns=train_set.columns)
        results = lof.predict(scaled_dataset)
        
        conf_matrix = confusion_matrix(user_labels.drop(drop_train_rows).values,results)
        #display_confusion_matrix(conf_matrix)
        true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)
        tpr_list = np.append(tpr_list,true_positive_rate)
        tnr_list = np.append(tnr_list,true_negative_rate)
        
    average_tpr = tpr_list.mean()
    average_tnr = tnr_list.mean()
    
    print(f"Average true positive rate: {average_tpr}")
    print(f"Average true negative rate: {average_tnr}")
    
test_function(train_dataset, class_column="subject")

"""
# Out:
# '\n\n\nfrom sklearn.preprocessing import StandardScaler,MinMaxScaler\nfrom sklearn.neighbors import LocalOutlierFactor\nfrom sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay\nfrom sklearn.model_selection import StratifiedShuffleSplit\nimport matplotlib.pyplot as plt\n\n\ndef calculate_metrics(conf_matrix):\n    true_positive_rate = conf_matrix[1,1] / conf_matrix[1,:].sum()\n    true_negative_rate = conf_matrix[0,0] / conf_matrix[0,:].sum()\n\n    return true_positive_rate, true_negative_rate\n\n\ndef display_confusion_matrix(conf_matrix):\n    print(conf_matrix)\n        \n    fig, ax = plt.subplots(figsize=(10,10))\n    display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix,display_labels=["Imposter","User"])\n    display.plot(cmap=plt.cm.Blues, values_format="d",ax=ax)\n\n    true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)\n    \n    print(f"True positive rate: {true_positive_rate}")\n    print(f"True negative rate: {true_negative_rate}")\n\ndef test_function(dataset, class_column = "user"):\n    \n    if class_column not in dataset.columns:\n        msg = (f"class_column "{class_column}" does not exist in dataset")\n        raise KeyError(msg)\n\n    #sss = StratifiedShuffleSplit(2,test_size=0.01,random_state=42)\n    #generator = sss.split(train_dataset,train_dataset["subject"])\n    #_, indices = next(generator)\n    #stratified_dataset = dataset.iloc[indices]\n    #dataset = pd.concat([stratified_dataset,dataset.loc[dataset.subject == "s040"][:75]])\n        \n    class_list = dataset[class_column].unique()\n    labels = dataset[class_column].copy()\n    dataset = dataset.drop(class_column,axis=1)\n    tpr_list = np.array([])\n    tnr_list = np.array([])\n\n    for i in class_list:\n        \n        print(f"User #{i}")\n        \n        user_labels = labels.copy()\n        user_labels[user_labels != i] = -1\n        user_labels[user_labels == i] = 1\n        user_labels = user_labels.astype("int32")\n        \n        # Selecting only the first 50 elements to train on\n        \n        train_set = dataset.loc[user_labels==1].sample(50,random_state=42)\n        drop_train_rows = train_set.index\n        \n\n        scaler = StandardScaler()\n        scaled_train_set = pd.DataFrame(scaler.fit_transform(train_set),columns=train_set.columns)\n        \n        lof = LocalOutlierFactor(n_neighbors=10, novelty=True, contamination=0.15)\n        lof.fit(scaled_train_set)\n        \n        scaled_dataset = pd.DataFrame(scaler.transform(dataset.drop(drop_train_rows)),columns=train_set.columns)\n        results = lof.predict(scaled_dataset)\n        \n        conf_matrix = confusion_matrix(user_labels.drop(drop_train_rows).values,results)\n        #display_confusion_matrix(conf_matrix)\n        true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)\n        tpr_list = np.append(tpr_list,true_positive_rate)\n        tnr_list = np.append(tnr_list,true_negative_rate)\n        \n    average_tpr = tpr_list.mean()\n    average_tnr = tnr_list.mean()\n    \n    print(f"Average true positive rate: {average_tpr}")\n    print(f"Average true negative rate: {average_tnr}")\n    \ntest_function(train_dataset, class_column="subject")\n\n'

# %% [markdown]
# # ABOD

# %%
from sklearn.model_selection import StratifiedKFold

user_data = data.loc[data["subject"]=="s002"].sample(frac=1).reset_index(drop=True)
user_train_data = user_data[0:200]
user_test_data = user_data[200:400]

other_data = data[data["subject"]!="s002"].reset_index(drop=True)
skf = StratifiedKFold(n_splits=50,shuffle=True)
gen = skf.split(other_data,other_data["subject"])

imposter_train_indices = next(gen)[1]
imposter_train_data = other_data.loc[imposter_train_indices]

imposter_test_indices = next(gen)[1]
imposter_train_data = other_data.loc[imposter_test_indices]

pd.concat([user_train_data,imposter_train_data],axis=0)
# Out:
#       subject  H.period  DD.period.t  UD.period.t     H.t  DD.t.i  UD.t.i  \
# 0        s002    0.0900       0.1095       0.0195  0.0837  0.1389  0.0552
# 1        s002    0.1077       0.1942       0.0865  0.0887  0.1431  0.0544
# 2        s002    0.1185       0.1855       0.0670  0.0858  0.1399  0.0541
# 3        s002    0.1283       0.1818       0.0535  0.1177  0.1660  0.0483
# 4        s002    0.1241       0.2019       0.0778  0.0829  0.1745  0.0916
# ...       ...       ...          ...          ...     ...     ...     ...
# 19896    s057    0.0913       0.1253       0.0340  0.0876  0.1240  0.0364
# 19957    s057    0.0778       0.1268       0.0490  0.1005  0.1206  0.0201
# 19967    s057    0.0778       0.1154       0.0376  0.0821  0.0689 -0.0132
# 19971    s057    0.0670       0.0988       0.0318  0.0905  0.0886 -0.0019
# 19976    s057    0.0840       0.0783      -0.0057  0.0995  0.1436  0.0441
#
#           H.i  DD.i.e  UD.i.e  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0      0.0726  0.0620 -0.0106  ...  0.1051  0.1751  0.0700  0.0797  0.1802
# 1      0.0652  0.1328  0.0676  ...  0.1075  0.0758 -0.0317  0.0896  0.2091
# 2      0.0932  0.1653  0.0721  ...  0.1307  0.1759  0.0452  0.0708  0.2318
# 3      0.1074  0.0839 -0.0235  ...  0.1225  0.1164 -0.0061  0.1136  0.2421
# 4      0.0734  0.1310  0.0576  ...  0.1307  0.1413  0.0106  0.0845  0.2505
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 19896  0.0778  0.0799  0.0021  ...  0.0907  0.1047  0.0140  0.0831  0.0820
# 19957  0.0699  0.0641 -0.0058  ...  0.1224  0.0847 -0.0377  0.0776  0.1127
# 19967  0.0976  0.1219  0.0243  ...  0.1011  0.0681 -0.0330  0.0631  0.1024
# 19971  0.0974  0.0913 -0.0061  ...  0.0966  0.0655 -0.0311  0.0844  0.0646
# 19976  0.0707  0.0393 -0.0314  ...  0.0905  0.1154  0.0249  0.0873  0.1928
#
#        UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# 0      0.1005  0.0892       0.2144       0.1252    0.1048
# 1      0.1195  0.1159       0.2509       0.1350    0.0710
# 2      0.1610  0.0974       0.3044       0.2070    0.0834
# 3      0.1285  0.1552       0.2382       0.0830    0.1293
# 4      0.1660  0.0813       0.3092       0.2279    0.0821
# ...       ...     ...          ...          ...       ...
# 19896 -0.0011  0.1322       0.2331       0.1009    0.1074
# 19957  0.0351  0.0828       0.2159       0.1331    0.1079
# 19967  0.0393  0.1111       0.1912       0.0801    0.1166
# 19971 -0.0198  0.1195       0.2199       0.1004    0.1016
# 19976  0.1055  0.1024       0.1975       0.0951    0.1134
#
# [600 rows x 32 columns]

# %%
X_test.shape
# Out:
# (5100, 31)

# %%
from sklearn.model_selection import StratifiedKFold
from pyod.models.abod import ABOD
from pyod.models.copod import COPOD
from sklearn.svm import OneClassSVM

def calculate_metrics(conf_matrix):
    true_positive_rate = conf_matrix[1,1] / conf_matrix[1,:].sum()
    true_negative_rate = conf_matrix[0,0] / conf_matrix[0,:].sum()

    return true_positive_rate, true_negative_rate


def display_confusion_matrix(conf_matrix):
    print(conf_matrix)
        
    fig, ax = plt.subplots(figsize=(10,10))
    display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix,display_labels=["Imposter","User"])
    display.plot(cmap=plt.cm.Blues, values_format="d",ax=ax)

    true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)
    
    print(f"True positive rate: {true_positive_rate}")
    print(f"True negative rate: {true_negative_rate}")


    
def test_function(dataset, class_column = "user"):
    
    if class_column not in dataset.columns:
        msg = (f"class_column \"{class_column}\" does not exist in dataset")
        raise KeyError(msg)
        
    class_list = dataset[class_column].unique()
    tpr_list = np.array([])
    tnr_list = np.array([])

    for i in class_list:
        
        print(f"User #{i}")
        
        user_data = dataset.loc[dataset[class_column]==i].sample(frac=1).reset_index(drop=True)
        user_train_data = user_data[0:200]
        user_test_data = user_data[200:400]

        other_data = data[data[class_column]!=i].reset_index(drop=True)
        skf = StratifiedKFold(n_splits=100,shuffle=True)
        gen = skf.split(other_data,other_data[class_column])

        imposter_train_indices = next(gen)[1]
        imposter_train_data = other_data.loc[imposter_train_indices]

        imposter_test_indices = next(gen)[1]
        imposter_test_data = other_data.loc[imposter_test_indices]
        
        train_set = pd.concat([user_train_data,imposter_train_data],axis=0,sort=True).drop(class_column,axis=1)
        test_set = pd.concat([user_test_data,imposter_test_data],axis=0,sort=True)
        
        user_labels = test_set[class_column].copy()
        user_labels[user_labels != i] = -1
        user_labels[user_labels == i] = 1
        user_labels = user_labels.astype("int32")

        scaler = StandardScaler()
        scaled_train_set = pd.DataFrame(scaler.fit_transform(train_set),columns=train_set.columns)
        
        abod = OneClassSVM(kernel="rbf",gamma=0.1,nu=0.5)
        abod.fit(scaled_train_set)
        
        scaled_test_set = pd.DataFrame(scaler.transform(test_set.drop(class_column,axis=1)),columns=train_set.columns)
        results = abod.predict(scaled_test_set)

        conf_matrix = confusion_matrix(user_labels.values,results)
        #display_confusion_matrix(conf_matrix)
        true_positive_rate, true_negative_rate = calculate_metrics(conf_matrix)
        tpr_list = np.append(tpr_list,true_positive_rate)
        tnr_list = np.append(tnr_list,true_negative_rate)
        
    average_tpr = tpr_list.mean()
    average_tnr = tnr_list.mean()
    
    print(f"Average true positive rate: {average_tpr}")
    print(f"Average true negative rate: {average_tnr}")
    
test_function(train_dataset, class_column="subject")
# Out:
# User #s002
# User #s003
# User #s004
# User #s005
# User #s007
# User #s008
# User #s010
# User #s011
# User #s012
# User #s013
# User #s015
# User #s016
# User #s017
# User #s018
# User #s019
# User #s020
# User #s021
# User #s022
# User #s024
# User #s025
# User #s026
# User #s027
# User #s028
# User #s029
# User #s030
# User #s031
# User #s032
# User #s033
# User #s034
# User #s035
# User #s036
# User #s037
# User #s038
# User #s039
# User #s040
# User #s041
# User #s042
# User #s043
# User #s044
# User #s046
# User #s047
# User #s048
# User #s049
# User #s050
# User #s051
# User #s052
# User #s053
# User #s054
# User #s055
# User #s056
# User #s057
# Average true positive rate: 0.6566666666666667
# Average true negative rate: 0.7114705882352941

# %% [markdown]
# # AutoEncoder

# %%
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit

class AnomalyDetector(Model):
    def __init__(self):
        super(AnomalyDetector, self).__init__()
        self.encoder = tf.keras.Sequential([
            keras.layers.Dense(64, activation="relu"),
            keras.layers.Dense(32, activation="relu"),
            keras.layers.Dense(8, activation="relu")])

        self.decoder = tf.keras.Sequential([
            keras.layers.Dense(32, activation="relu"),
            keras.layers.Dense(64, activation="relu"),
            keras.layers.Dense(31, activation="sigmoid")])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

def train_autoencoder(train_data,validation_data,epochs=50,batch_size=16):

    autoencoder = AnomalyDetector()

    autoencoder.compile(optimizer="nadam", loss="mae")

    history = autoencoder.fit(train_data,train_data,
                             epochs=epochs,
                             batch_size=batch_size,
                             shuffle=True,
                             verbose = 0,
                             validation_data=(validation_data, validation_data))

    return autoencoder, history

def show_history(history):
    fig1, ax1 = plt.subplots()
    ax1.plot(history.history["loss"], label="Training Loss")
    ax1.plot(history.history["val_loss"], label="Validation Loss")
    ax1.legend()
    plt.show()

def calculate_rec_loss(autoencoder, data):
    reconstructions = autoencoder.predict(data)
    train_loss = tf.keras.losses.mae(reconstructions, data)
    return train_loss

def show_distributions(normal_loss,anomal_loss, title="Figure"):
    fig1, ax1 = plt.subplots()
    ax1.hist(normal_loss[None,:], bins=60,alpha=0.5,label="Normal data",range=(0,6))
    ax1.hist(anomal_loss[None,:], bins=60,alpha=0.5,label="Anomal data",range=(0,6))
    ax1.set_xlabel("Reconstruction errors")
    ax1.set_ylabel("Number of examples")
    ax1.set_title(title)
    ax1.legend()
    plt.show()

def predict(model, data, threshold):
    reconstructions = model.predict(data)
    loss = tf.keras.losses.mae(reconstructions, data)
    return tf.math.less(loss, threshold)

def specificity(labels,preds):
    tn, fp, fn, tp = confusion_matrix(labels,preds).ravel()
    return tn / (tn+fp)

def calculate_stats(preds, labels):
    acc = accuracy_score(labels, preds)
    spec = specificity(labels, preds)
    recall = recall_score(labels, preds)
    
    return acc,spec,recall

def find_threshold(normal_loss,anomal_loss):

    best_threshold = 0
    best_difference = 1
    counter = 0
    for threshold in np.linspace(0.5,2,150):
        normal_percentage = tf.math.less(normal_loss, threshold).numpy().sum() / normal_loss.shape[0]
        anomal_percentage = tf.math.greater(anomal_loss, threshold).numpy().sum() / anomal_loss.shape[0]
        difference = abs(normal_percentage - anomal_percentage)
        if difference < best_difference:
            best_difference = difference
            best_threshold = threshold
            counter = 0
        else:
            counter += 1
            if counter >= 5:
                break
            
    return best_threshold

# %%
class Subject():
    def __init__(self, name, autoencoder, best_threshold,scaler):
        self.name = name
        self.autoencoder = autoencoder
        self.best_threshold = best_threshold
        self.scaler = scaler
        

def train_subject(subject, dataset, train_samples=50, anomal_samples=250, display=False):
    
    NORMAL_TEST_LEN = 250
    PERCENTAGE = anomal_samples / dataset.shape[0]
    
    ss = StandardScaler()

    # Data for training the encoder
    normal_data = dataset.loc[dataset["subject"]==subject].sample(train_samples,random_state=42).drop("subject",axis=1)
    normal_scaled_data = ss.fit_transform(normal_data)
 
    normal_test_data = dataset.loc[dataset["subject"]==subject].drop(normal_data.index).drop("subject",axis=1).sample(NORMAL_TEST_LEN,random_state=42)

    # Stratified Sampling of 500 anomalies from dataset (10 from each class)
    sss = StratifiedShuffleSplit(n_splits=1, test_size=PERCENTAGE,random_state=42)
    generator = sss.split(dataset,dataset["subject"])
    _, indices = next(generator)
    anomal_test_data = dataset.iloc[indices]
    anomal_test_data = anomal_test_data[anomal_test_data["subject"]!=subject].drop("subject",axis=1)
    anomal_len = anomal_test_data.shape[0]
    
    # Scaling
    anomal_test_scaled_data = ss.transform(anomal_test_data)
    normal_test_scaled_data = ss.transform(normal_test_data)

    test_data = pd.concat([normal_test_data,anomal_test_data],axis=0)
    test_data_scaled = ss.transform(test_data)
    test_data_labels = np.array([True] * NORMAL_TEST_LEN + [False] * anomal_len)
    
    autoencoder, history = train_autoencoder(normal_scaled_data, test_data_scaled, epochs=75,batch_size=16)
    
    normal_loss = calculate_rec_loss(autoencoder,normal_test_scaled_data)
    anomal_loss = calculate_rec_loss(autoencoder,anomal_test_scaled_data)

    best_threshold = find_threshold(normal_loss,anomal_loss)
    
    preds = predict(autoencoder,test_data_scaled,best_threshold)
    acc,spec,recall = calculate_stats(preds,test_data_labels)
    
    if display:
        show_history(history)
        show_distributions(normal_loss, anomal_loss, title=subject)

        print("Accuracy = {}".format(acc))
        print("Specificity(True negative rate) = {}".format(spec))
        print("Recall(True positive rate) = {}".format(recall))

        print("Best threshold:",best_threshold)
    
    return Subject(subject,autoencoder,best_threshold,ss)
    
train_subject("s002",train_dataset,50,250,display=True)
# Out:
# Accuracy = 0.8145161290322581
# Specificity(True negative rate) = 0.8130081300813008
# Recall(True positive rate) = 0.816
# Best threshold: 0.8523489932885906

# %%
subject_list = {}

def train(dataset):
    for subject in train_dataset["subject"].unique():
        sub_object = train_subject(subject,dataset,250,250,display=True)
        subject_list[subject] = sub_object

train(train_dataset)
# Out:
# Accuracy = 0.8346774193548387
# Specificity(True negative rate) = 0.8333333333333334
# Recall(True positive rate) = 0.836
# Best threshold: 0.7416107382550335
# Accuracy = 0.8951612903225806
# Specificity(True negative rate) = 0.8983739837398373
# Recall(True positive rate) = 0.892
# Best threshold: 0.7919463087248322
# Accuracy = 0.905241935483871
# Specificity(True negative rate) = 0.9024390243902439
# Recall(True positive rate) = 0.908
# Best threshold: 0.7818791946308725
# Accuracy = 0.9536290322580645
# Specificity(True negative rate) = 0.9552845528455285
# Recall(True positive rate) = 0.952
# Best threshold: 0.9932885906040267
# Accuracy = 0.8709677419354839
# Specificity(True negative rate) = 0.8658536585365854
# Recall(True positive rate) = 0.876
# Best threshold: 0.7315436241610738
# Accuracy = 0.8850806451612904
# Specificity(True negative rate) = 0.8861788617886179
# Recall(True positive rate) = 0.884
# Best threshold: 0.7516778523489933
# Accuracy = 0.9556451612903226
# Specificity(True negative rate) = 0.9552845528455285
# Recall(True positive rate) = 0.956
# Best threshold: 0.9328859060402684
# Accuracy = 0.8649193548387096
# Specificity(True negative rate) = 0.8658536585365854
# Recall(True positive rate) = 0.864
# Best threshold: 0.7516778523489933
# Accuracy = 0.9233870967741935
# Specificity(True negative rate) = 0.9227642276422764
# Recall(True positive rate) = 0.924
# Best threshold: 0.8523489932885906
# Accuracy = 0.8931451612903226
# Specificity(True negative rate) = 0.8943089430894309
# Recall(True positive rate) = 0.892
# Best threshold: 0.832214765100671
# Accuracy = 0.8185483870967742
# Specificity(True negative rate) = 0.8170731707317073
# Recall(True positive rate) = 0.82
# Best threshold: 0.6912751677852349
# Accuracy = 0.9637096774193549
# Specificity(True negative rate) = 0.9634146341463414
# Recall(True positive rate) = 0.964
# Best threshold: 0.9328859060402684
# Accuracy = 0.9557344064386318
# Specificity(True negative rate) = 0.9554655870445344
# Recall(True positive rate) = 0.956
# Best threshold: 0.9731543624161074
# Accuracy = 0.8104838709677419
# Specificity(True negative rate) = 0.8170731707317073
# Recall(True positive rate) = 0.804
# Best threshold: 0.7114093959731543
# Accuracy = 0.9616935483870968
# Specificity(True negative rate) = 0.9634146341463414
# Recall(True positive rate) = 0.96
# Best threshold: 0.9832214765100671
# Accuracy = 0.7782258064516129
# Specificity(True negative rate) = 0.7804878048780488
# Recall(True positive rate) = 0.776
# Best threshold: 0.651006711409396
# Accuracy = 0.8810483870967742
# Specificity(True negative rate) = 0.8821138211382114
# Recall(True positive rate) = 0.88
# Best threshold: 0.7013422818791946
# Accuracy = 0.9717741935483871
# Specificity(True negative rate) = 0.9878048780487805
# Recall(True positive rate) = 0.956
# Best threshold: 0.8825503355704698
# Accuracy = 0.9596774193548387
# Specificity(True negative rate) = 0.959349593495935
# Recall(True positive rate) = 0.96
# Best threshold: 0.9832214765100671
# Accuracy = 0.9294354838709677
# Specificity(True negative rate) = 0.926829268292683
# Recall(True positive rate) = 0.932
# Best threshold: 0.9228187919463087
# Accuracy = 0.9375
# Specificity(True negative rate) = 0.9349593495934959
# Recall(True positive rate) = 0.94
# Best threshold: 0.8523489932885906
# Accuracy = 0.9435483870967742
# Specificity(True negative rate) = 0.943089430894309
# Recall(True positive rate) = 0.944
# Best threshold: 0.8825503355704698
# Accuracy = 0.9556451612903226
# Specificity(True negative rate) = 0.9552845528455285
# Recall(True positive rate) = 0.956
# Best threshold: 0.9530201342281879
# Accuracy = 0.9153225806451613
# Specificity(True negative rate) = 0.9146341463414634
# Recall(True positive rate) = 0.916
# Best threshold: 0.7818791946308725
# Accuracy = 0.9153225806451613
# Specificity(True negative rate) = 0.9146341463414634
# Recall(True positive rate) = 0.916
# Best threshold: 0.8523489932885906
# Accuracy = 0.782258064516129
# Specificity(True negative rate) = 0.7886178861788617
# Recall(True positive rate) = 0.776
# Best threshold: 0.7114093959731543
# Accuracy = 0.7762096774193549
# Specificity(True negative rate) = 0.7804878048780488
# Recall(True positive rate) = 0.772
# Best threshold: 0.610738255033557
# Accuracy = 0.9274193548387096
# Specificity(True negative rate) = 0.926829268292683
# Recall(True positive rate) = 0.928
# Best threshold: 0.87248322147651
# Accuracy = 0.8145161290322581
# Specificity(True negative rate) = 0.8048780487804879
# Recall(True positive rate) = 0.824
# Best threshold: 0.6610738255033557
# Accuracy = 0.8326612903225806
# Specificity(True negative rate) = 0.8333333333333334
# Recall(True positive rate) = 0.832
# Best threshold: 0.7516778523489933
# Accuracy = 0.9576612903225806
# Specificity(True negative rate) = 1.0
# Recall(True positive rate) = 0.916
# Best threshold: 0.7919463087248322
# Accuracy = 0.8467741935483871
# Specificity(True negative rate) = 0.8495934959349594
# Recall(True positive rate) = 0.844
# Best threshold: 0.7013422818791946
# Accuracy = 0.8790322580645161
# Specificity(True negative rate) = 0.8780487804878049
# Recall(True positive rate) = 0.88
# Best threshold: 0.7818791946308725
# Accuracy = 0.9274193548387096
# Specificity(True negative rate) = 0.9227642276422764
# Recall(True positive rate) = 0.932
# Best threshold: 0.832214765100671
# Accuracy = 0.8911290322580645
# Specificity(True negative rate) = 0.8943089430894309
# Recall(True positive rate) = 0.888
# Best threshold: 0.832214765100671
# Accuracy = 0.8870967741935484
# Specificity(True negative rate) = 0.8821138211382114
# Recall(True positive rate) = 0.892
# Best threshold: 0.802013422818792
# Accuracy = 0.9556451612903226
# Specificity(True negative rate) = 0.9552845528455285
# Recall(True positive rate) = 0.956
# Best threshold: 0.9530201342281879
# Accuracy = 0.9879032258064516
# Specificity(True negative rate) = 0.9959349593495935
# Recall(True positive rate) = 0.98
# Best threshold: 0.9530201342281879
# Accuracy = 0.9133064516129032
# Specificity(True negative rate) = 0.9105691056910569
# Recall(True positive rate) = 0.916
# Best threshold: 0.8825503355704698
# Accuracy = 0.844758064516129
# Specificity(True negative rate) = 0.8414634146341463
# Recall(True positive rate) = 0.848
# Best threshold: 0.7013422818791946
# Accuracy = 0.8269617706237424
# Specificity(True negative rate) = 0.8259109311740891
# Recall(True positive rate) = 0.828
# Best threshold: 0.7013422818791946
# Accuracy = 0.9133064516129032
# Specificity(True negative rate) = 0.9105691056910569
# Recall(True positive rate) = 0.916
# Best threshold: 0.8221476510067114
# Accuracy = 0.9294354838709677
# Specificity(True negative rate) = 0.9308943089430894
# Recall(True positive rate) = 0.928
# Best threshold: 0.8120805369127517
# Accuracy = 0.8611670020120724
# Specificity(True negative rate) = 0.8623481781376519
# Recall(True positive rate) = 0.86
# Best threshold: 0.761744966442953
# Accuracy = 0.844758064516129
# Specificity(True negative rate) = 0.8414634146341463
# Recall(True positive rate) = 0.848
# Best threshold: 0.761744966442953
# Accuracy = 0.9838709677419355
# Specificity(True negative rate) = 0.983739837398374
# Recall(True positive rate) = 0.984
# Best threshold: 1.1140939597315436
# Accuracy = 0.9557344064386318
# Specificity(True negative rate) = 0.9554655870445344
# Recall(True positive rate) = 0.956
# Best threshold: 0.8624161073825503
# Accuracy = 0.9133064516129032
# Specificity(True negative rate) = 0.9146341463414634
# Recall(True positive rate) = 0.912
# Best threshold: 0.7315436241610738
# Accuracy = 0.9556451612903226
# Specificity(True negative rate) = 0.9552845528455285
# Recall(True positive rate) = 0.956
# Best threshold: 1.0536912751677852
# Accuracy = 0.875
# Specificity(True negative rate) = 0.8699186991869918
# Recall(True positive rate) = 0.88
# Best threshold: 0.761744966442953
# Accuracy = 0.8387096774193549
# Specificity(True negative rate) = 0.8373983739837398
# Recall(True positive rate) = 0.84
# Best threshold: 0.7214765100671141

# %%
test_dataset = pd.concat([y_test,X_test],axis=1)
test_dataset = test_dataset.reset_index(drop=True)
test_dataset
# Out:
#      subject  H.period  DD.period.t  UD.period.t     H.t  DD.t.i  UD.t.i  \
# 0       s022    0.0533       0.4910       0.4377  0.0531  0.3334  0.2803
# 1       s027    0.1164       0.1979       0.0815  0.0911  0.1394  0.0483
# 2       s021    0.1051       0.2415       0.1364  0.0818  0.1729  0.0911
# 3       s046    0.1016       0.3172       0.2156  0.1150  0.2366  0.1216
# 4       s020    0.0839       0.1527       0.0688  0.0987  0.1428  0.0441
# ...      ...       ...          ...          ...     ...     ...     ...
# 5095    s037    0.0958       0.1094       0.0136  0.0744  0.1319  0.0575
# 5096    s018    0.0644       0.1453       0.0809  0.0602  0.2312  0.1710
# 5097    s033    0.0636       0.4657       0.4021  0.1646  0.1092 -0.0554
# 5098    s033    0.1245       0.2587       0.1342  0.1873  0.1630 -0.0243
# 5099    s032    0.1114       0.0999      -0.0115  0.1109  0.1663  0.0554
#
#          H.i  DD.i.e  UD.i.e  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0     0.0415  0.2550  0.2135  ...  0.0895  0.2067  0.1172  0.0570  0.3114
# 1     0.1338  0.1066 -0.0272  ...  0.1259  0.1363  0.0104  0.1093  0.1600
# 2     0.0979  0.1811  0.0832  ...  0.0433  0.1508  0.1075  0.0771  0.2394
# 3     0.0586  0.1855  0.1269  ...  0.1132  0.1354  0.0222  0.0894  0.2065
# 4     0.1051  0.1220  0.0169  ...  0.1119  0.1906  0.0787  0.1386  0.1243
# ...      ...     ...     ...  ...     ...     ...     ...     ...     ...
# 5095  0.0544  0.0979  0.0435  ...  0.1032  0.0942 -0.0090  0.1177  0.3229
# 5096  0.0739  0.1199  0.0460  ...  0.0380  0.0837  0.0457  0.0713  0.1249
# 5097  0.1332  0.2058  0.0726  ...  0.2190  0.1765 -0.0425  0.0742  0.2683
# 5098  0.1681  0.2686  0.1005  ...  0.1900  0.1446 -0.0454  0.1396  0.2169
# 5099  0.0789  0.0644 -0.0145  ...  0.0940  0.1460  0.0520  0.0791  0.1611
#
#       UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# 0     0.2544  0.0525       0.6891       0.6366    0.0647
# 1     0.0507  0.1206       0.2791       0.1585    0.0871
# 2     0.1623  0.0945       0.3567       0.2622    0.0689
# 3     0.1171  0.1187       0.2818       0.1631    0.0728
# 4    -0.0143  0.1267       0.2074       0.0807    0.0850
# ...      ...     ...          ...          ...       ...
# 5095  0.2052  0.1074       0.2724       0.1650    0.0897
# 5096  0.0536  0.0964       0.2797       0.1833    0.0111
# 5097  0.1941  0.1034       0.4522       0.3488    0.1203
# 5098  0.0773  0.1590       0.3266       0.1676    0.1016
# 5099  0.0820  0.0749       0.1639       0.0890    0.0802
#
# [5100 rows x 32 columns]

# %%
test_dataset = test_dataset.reset_index(drop=True)

def test_subject(subject, dataset):
    y_test = dataset["subject"] == subject.name
    x_test = dataset.drop("subject",axis=1)
    x_test_scaled = subject.scaler.transform(x_test)
    preds = predict(subject.autoencoder,x_test_scaled,subject.best_threshold)
    acc,spec,recall = calculate_stats(preds,y_test)
    print("Accuracy = {}".format(acc))
    print("Specificity(True negative rate) = {}".format(spec))
    print("Recall(True positive rate) = {}".format(recall))
    return acc,spec,recall
    
def test(dataset, subject_list):
    acc_list=[]
    spec_list=[]
    recall_list=[]
    for subject in dataset["subject"].unique():
        print("------------------")
        print("Subject:",subject)
        print("------------------")
        acc,spec,recall = test_subject(subject_list[subject],dataset)
        acc_list.append(acc)
        spec_list.append(spec)
        recall_list.append(recall)
    print("------------------")
    print("AVERAGE RESULTS")
    print("------------------")
    print("Accuracy = {}".format(np.array(acc_list).mean()))
    print("Specificity(True negative rate) = {}".format(np.array(spec_list).mean()))
    print("Recall(True positive rate) = {}".format(np.array(recall_list).mean()))

# %%
test(test_dataset, subject_list)
# Out:
# ------------------
# Subject: s022
# ------------------
# Accuracy = 0.9866666666666667
# Specificity(True negative rate) = 0.9882
# Recall(True positive rate) = 0.91
# ------------------
# Subject: s027
# ------------------
# Accuracy = 0.9429411764705883
# Specificity(True negative rate) = 0.9434
# Recall(True positive rate) = 0.92
# ------------------
# Subject: s021
# ------------------
# Accuracy = 0.8884313725490196
# Specificity(True negative rate) = 0.8902
# Recall(True positive rate) = 0.8
# ------------------
# Subject: s046
# ------------------
# Accuracy = 0.8466666666666667
# Specificity(True negative rate) = 0.8484
# Recall(True positive rate) = 0.76
# ------------------
# Subject: s020
# ------------------
# Accuracy = 0.8241176470588235
# Specificity(True negative rate) = 0.8272
# Recall(True positive rate) = 0.67
# ------------------
# Subject: s031
# ------------------
# Accuracy = 0.8025490196078431
# Specificity(True negative rate) = 0.804
# Recall(True positive rate) = 0.73
# ------------------
# Subject: s052
# ------------------
# Accuracy = 0.9898039215686274
# Specificity(True negative rate) = 0.9904
# Recall(True positive rate) = 0.96
# ------------------
# Subject: s012
# ------------------
# Accuracy = 0.941764705882353
# Specificity(True negative rate) = 0.9436
# Recall(True positive rate) = 0.85
# ------------------
# Subject: s011
# ------------------
# Accuracy = 0.875686274509804
# Specificity(True negative rate) = 0.877
# Recall(True positive rate) = 0.81
# ------------------
# Subject: s040
# ------------------
# Accuracy = 0.8892156862745098
# Specificity(True negative rate) = 0.8902
# Recall(True positive rate) = 0.84
# ------------------
# Subject: s048
# ------------------
# Accuracy = 0.8915686274509804
# Specificity(True negative rate) = 0.8924
# Recall(True positive rate) = 0.85
# ------------------
# Subject: s005
# ------------------
# Accuracy = 0.952156862745098
# Specificity(True negative rate) = 0.9528
# Recall(True positive rate) = 0.92
# ------------------
# Subject: s043
# ------------------
# Accuracy = 0.9923529411764705
# Specificity(True negative rate) = 0.9936
# Recall(True positive rate) = 0.93
# ------------------
# Subject: s008
# ------------------
# Accuracy = 0.8833333333333333
# Specificity(True negative rate) = 0.8836
# Recall(True positive rate) = 0.87
# ------------------
# Subject: s002
# ------------------
# Accuracy = 0.8619607843137255
# Specificity(True negative rate) = 0.8632
# Recall(True positive rate) = 0.8
# ------------------
# Subject: s016
# ------------------
# Accuracy = 0.9558823529411765
# Specificity(True negative rate) = 0.9574
# Recall(True positive rate) = 0.88
# ------------------
# Subject: s053
# ------------------
# Accuracy = 0.9586274509803921
# Specificity(True negative rate) = 0.9612
# Recall(True positive rate) = 0.83
# ------------------
# Subject: s036
# ------------------
# Accuracy = 0.9986274509803922
# Specificity(True negative rate) = 1.0
# Recall(True positive rate) = 0.93
# ------------------
# Subject: s033
# ------------------
# Accuracy = 0.9168627450980392
# Specificity(True negative rate) = 0.9166
# Recall(True positive rate) = 0.93
# ------------------
# Subject: s049
# ------------------
# Accuracy = 0.9274509803921569
# Specificity(True negative rate) = 0.9276
# Recall(True positive rate) = 0.92
# ------------------
# Subject: s035
# ------------------
# Accuracy = 0.8515686274509804
# Specificity(True negative rate) = 0.8524
# Recall(True positive rate) = 0.81
# ------------------
# Subject: s055
# ------------------
# Accuracy = 0.9458823529411765
# Specificity(True negative rate) = 0.946
# Recall(True positive rate) = 0.94
# ------------------
# Subject: s034
# ------------------
# Accuracy = 0.8245098039215686
# Specificity(True negative rate) = 0.8258
# Recall(True positive rate) = 0.76
# ------------------
# Subject: s017
# ------------------
# Accuracy = 0.9674509803921568
# Specificity(True negative rate) = 0.9676
# Recall(True positive rate) = 0.96
# ------------------
# Subject: s010
# ------------------
# Accuracy = 0.9464705882352941
# Specificity(True negative rate) = 0.9464
# Recall(True positive rate) = 0.95
# ------------------
# Subject: s056
# ------------------
# Accuracy = 0.8754901960784314
# Specificity(True negative rate) = 0.8756
# Recall(True positive rate) = 0.87
# ------------------
# Subject: s028
# ------------------
# Accuracy = 0.9584313725490196
# Specificity(True negative rate) = 0.9578
# Recall(True positive rate) = 0.99
# ------------------
# Subject: s032
# ------------------
# Accuracy = 0.779607843137255
# Specificity(True negative rate) = 0.7832
# Recall(True positive rate) = 0.6
# ------------------
# Subject: s018
# ------------------
# Accuracy = 0.8323529411764706
# Specificity(True negative rate) = 0.8352
# Recall(True positive rate) = 0.69
# ------------------
# Subject: s044
# ------------------
# Accuracy = 0.9060784313725491
# Specificity(True negative rate) = 0.9056
# Recall(True positive rate) = 0.93
# ------------------
# Subject: s015
# ------------------
# Accuracy = 0.826078431372549
# Specificity(True negative rate) = 0.8264
# Recall(True positive rate) = 0.81
# ------------------
# Subject: s042
# ------------------
# Accuracy = 0.9780392156862745
# Specificity(True negative rate) = 0.9794
# Recall(True positive rate) = 0.91
# ------------------
# Subject: s026
# ------------------
# Accuracy = 0.943921568627451
# Specificity(True negative rate) = 0.945
# Recall(True positive rate) = 0.89
# ------------------
# Subject: s024
# ------------------
# Accuracy = 0.952156862745098
# Specificity(True negative rate) = 0.9528
# Recall(True positive rate) = 0.92
# ------------------
# Subject: s050
# ------------------
# Accuracy = 0.8572549019607844
# Specificity(True negative rate) = 0.8566
# Recall(True positive rate) = 0.89
# ------------------
# Subject: s057
# ------------------
# Accuracy = 0.8384313725490196
# Specificity(True negative rate) = 0.8386
# Recall(True positive rate) = 0.83
# ------------------
# Subject: s007
# ------------------
# Accuracy = 0.8994117647058824
# Specificity(True negative rate) = 0.9002
# Recall(True positive rate) = 0.86
# ------------------
# Subject: s054
# ------------------
# Accuracy = 0.9176470588235294
# Specificity(True negative rate) = 0.919
# Recall(True positive rate) = 0.85
# ------------------
# Subject: s047
# ------------------
# Accuracy = 0.8350980392156863
# Specificity(True negative rate) = 0.8362
# Recall(True positive rate) = 0.78
# ------------------
# Subject: s041
# ------------------
# Accuracy = 0.885686274509804
# Specificity(True negative rate) = 0.8868
# Recall(True positive rate) = 0.83
# ------------------
# Subject: s038
# ------------------
# Accuracy = 0.8737254901960785
# Specificity(True negative rate) = 0.8746
# Recall(True positive rate) = 0.83
# ------------------
# Subject: s013
# ------------------
# Accuracy = 0.8837254901960784
# Specificity(True negative rate) = 0.884
# Recall(True positive rate) = 0.87
# ------------------
# Subject: s025
# ------------------
# Accuracy = 0.943921568627451
# Specificity(True negative rate) = 0.9444
# Recall(True positive rate) = 0.92
# ------------------
# Subject: s004
# ------------------
# Accuracy = 0.9103921568627451
# Specificity(True negative rate) = 0.9098
# Recall(True positive rate) = 0.94
# ------------------
# Subject: s030
# ------------------
# Accuracy = 0.9194117647058824
# Specificity(True negative rate) = 0.9196
# Recall(True positive rate) = 0.91
# ------------------
# Subject: s003
# ------------------
# Accuracy = 0.886078431372549
# Specificity(True negative rate) = 0.8874
# Recall(True positive rate) = 0.82
# ------------------
# Subject: s029
# ------------------
# Accuracy = 0.9311764705882353
# Specificity(True negative rate) = 0.932
# Recall(True positive rate) = 0.89
# ------------------
# Subject: s037
# ------------------
# Accuracy = 0.8590196078431372
# Specificity(True negative rate) = 0.8606
# Recall(True positive rate) = 0.78
# ------------------
# Subject: s019
# ------------------
# Accuracy = 0.9613725490196079
# Specificity(True negative rate) = 0.9614
# Recall(True positive rate) = 0.96
# ------------------
# Subject: s051
# ------------------
# Accuracy = 0.8574509803921568
# Specificity(True negative rate) = 0.858
# Recall(True positive rate) = 0.83
# ------------------
# Subject: s039
# ------------------
# Accuracy = 0.9268627450980392
# Specificity(True negative rate) = 0.9272
# Recall(True positive rate) = 0.91
# ------------------
# AVERAGE RESULTS
# ------------------
# Accuracy = 0.9039484813533256
# Specificity(True negative rate) = 0.904835294117647
# Recall(True positive rate) = 0.8596078431372548

# %% [markdown]
# AVERAGE RESULTS
# ------------------
# ## 250 for training, 250 for best threshold (same instances)
#     Accuracy = 0.9039484813533256
#     Specificity(True negative rate) = 0.904835294117647
#     Recall(True positive rate) = 0.8596078431372548
# ## 50 for training, 250 for best threshold
#     Accuracy = 0.8760553633217993
#     Specificity(True negative rate) = 0.876278431372549
#     Recall(True positive rate) = 0.8649019607843137
# ## 20 for training, 250 for best threshold
#     Accuracy = 0.8783852364475202
#     Specificity(True negative rate) = 0.878643137254902
#     Recall(True positive rate) = 0.8654901960784314
# ## 50 for training, 50 for best threshold (same instances)
#     Accuracy = 0.9285121107266437
#     Specificity(True negative rate) = 0.9316745098039215
#     Recall(True positive rate) = 0.770392156862745
# ## 50 for training, 50 for best threshold (different instances)
#     Accuracy = 0.8971357170319108
#     Specificity(True negative rate) = 0.8989607843137255
#     Recall(True positive rate) = 0.8058823529411764
